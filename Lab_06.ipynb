# %% [markdown]
# # Lab 06

# %% [markdown]
# **Q1**: More fun with loops and dictionaries!!
#
# This week, we are going to work more on our gradebook code.  Let's consider that more grades have been added to the gradebook.  See the new gradebook dictionary below:

# %%
masterDictionary = dict()

masterDictionary['doe123'] = {'lab1': 100, 'lab2' : 100, 'lab3' : 95, 'lab4' : 90, 'lab5' : 100, 'project1' : 100, 'project2' : 95, 'project3' : 90}
masterDictionary['smith456'] = {'lab1': 100, 'lab2' : 80, 'lab3' : 70, 'lab4' : 90, 'lab5' : 100, 'project1' : 90, 'project2' : 88, 'project3' : 98}
masterDictionary['jones789'] = {'lab1': 100, 'lab2' : 80, 'lab3' : 70, 'lab4' : 90, 'lab5' : 100, 'project1' : 100, 'project2' : 85, 'project3' : 90}

# %% [markdown]
# For this question, we are going to project what the final project 4 grade needs to be for specific grades if _we assume the average for the labs **is the same** as the average for the first 5 labs.  To perform this caluclation, you need to get the total grade so far, using the same weightings used in lab 5.  We should calculate the necessary grade for an A+ (97% or better) A (93% - 96.9%), A- (90% - 92.9%), B+ (87% - 89.9%), and B (83% - 86.9%).  If it is not possible to earn a grade, given current scores and the projected average of the labs, indicate the grade is not possible.
#
# HINT: To calculate the grade you need you take the final grade needed (e.g. 97 for A+) minus the weighted total and divide that number by .2 the weighting of the final project 4.
#
# An example output from your program for the above grades would be:
#
#     Student doe123 current grade so far is : 96.69%
#          98.25% to get an A+
#          78.25% to get an A
#          63.25% to get an A-
#          48.25% to get an B+
#          28.25% to get an B
#
#     Student smith456 current grade so far is : 88.88%
#          It is not possible to get an A+
#          It is not possible to get an A
#          94.5% to get an A-
#          79.5% to get an B+
#          59.5% to get an B
#
#     Student jones789 current grade so far is : 89.25%
#          It is not possible to get an A+
#          It is not possible to get an A
#          93.0% to get an A-
#          78.0% to get an B+
#          58.0% to get an B

# %%
doeG = (masterDictionary['doe123']['lab1'] * 13.75) + (masterDictionary['doe123']['lab2'] * 13.75) + (masterDictionary['doe123']['lab3'] * 13.75) + (masterDictionary['doe123']['lab4'] * 13.75) + (masterDictionary['doe123']['project1'] * 10) + (masterDictionary['doe123']['project2'] * 10) + (masterDictionary['doe123']['project3'] * 5)
smithG = (masterDictionary['smith456']['lab1'] * 13.75) + (masterDictionary['smith456']['lab2'] * 13.75) + (masterDictionary['smith456']['lab3'] * 13.75) + (masterDictionary['smith456']['lab4'] * 13.75) + (masterDictionary['smith456']['project1'] * 10) + (masterDictionary['smith456']['project2'] * 10) + (masterDictionary['smith456']['project3'] * 5)
jonesG = (masterDictionary['jones789']['lab1'] * 13.75) + (masterDictionary['jones789']['lab2'] * 13.75) + (masterDictionary['jones789']['lab3'] * 13.75) + (masterDictionary['jones789']['lab4'] * 13.75) + (masterDictionary['jones789']['project1'] * 10) + (masterDictionary['jones789']['project2'] * 10) + (masterDictionary['jones789']['project3'] * 5)
weight = 13.75 + 13.75 + 13.75 + 13.75 + 10 + 10 + 5
doeP = round(doeG / weight, 2)
smithP = round(smithG / weight, 2)
jonesP = round(jonesG / weight, 2)
a = 97
a1 = 93
a2 = 90
b = 87
b1 = 83
b2 = 80

print("Student ID: 'doe123' grade so far is: " + str(doeP))

if ((a - ((1 - 0.2) * doeP)) / 0.2 > 100.0):
    print("It is not possible to get an A+")
else:
    print(str(round((a - ((1 - 0.2) * doeP)) / 0.2, 2)) + "% to get an A+")
    
if ((a1 - ((1 - 0.2) * doeP)) / 0.2 > 96.9):
    print("It is not possible to get an A")
else:
    print(str(round((a1 - ((1 - 0.2) * doeP)) / 0.2, 2)) + "% to get an A")
    
if ((a2 - ((1 - 0.2) * doeP)) / 0.2 > 92.9):
    print("It is not possible to get an A-")
else:
    print(str(round((a2 - ((1 - 0.2) * doeP)) / 0.2, 2)) + "% to get an A-")
    
if ((b - ((1 - 0.2) * doeP)) / 0.2 > 87.0):
    print("It is not possible to get an B+")
else:
    print(str(round((b - ((1 - 0.2) * doeP)) / 0.2, 2)) + "% to get an B+")
    
if ((b1 - ((1 - 0.2) * doeP)) / 0.2 > 83.0):
    print("It is not possible to get an B")
else:
    print(str(round((b1 - ((1 - 0.2) * doeP)) / 0.2, 2)) + "% to get an B")
    
print()    
print("Student ID: 'smith456' grade so far is: " + str(smithP))

if ((a - ((1 - 0.2) * smithP)) / 0.2 > 100.0):
    print("It is not possible to get an A+")
else:
    print(str(round((a - ((1 - 0.2) * smithP)) / 0.2, 2)) + "% to get an A+")
    
if ((a1 - ((1 - 0.2) * smithP)) / 0.2 > 96.9):
    print("It is not possible to get an A")
else:
    print(str(round((a1 - ((1 - 0.2) * smithP)) / 0.2, 2)) + "% to get an A")
    
if ((a2 - ((1 - 0.2) * smithP)) / 0.2 > 92.9):
    print("It is not possible to get an A-")
else:
    print(str(round((a2 - ((1 - 0.2) * smithP)) / 0.2, 2)) + "% to get an A-")
    
if ((b - ((1 - 0.2) * smithP)) / 0.2 > 87.0):
    print("It is not possible to get an B+")
else:
    print(str(round((b - ((1 - 0.2) * smithP)) / 0.2, 2)) + "% to get an B+")
    
if ((b1 - ((1 - 0.2) * smithP)) / 0.2 > 83.0):
    print("It is not possible to get an B")
else:
    print(str(round((b1 - ((1 - 0.2) * smithP)) / 0.2, 2)) + "% to get an B")
    
print()    
print("Student ID: 'jones789' grade so far is: " + str(jonesP))

if ((a - ((1 - 0.2) * jonesP)) / 0.2 > 100.0):
    print("It is not possible to get an A+")
else:
    print(str(round((a - ((1 - 0.2) * jonesP)) / 0.2, 2)) + "% to get an A+")
    
if ((a1 - ((1 - 0.2) * jonesP)) / 0.2 > 96.9):
    print("It is not possible to get an A")
else:
    print(str(round((a1 - ((1 - 0.2) * jonesP)) / 0.2, 2)) + "% to get an A")
    
if ((a2 - ((1 - 0.2) * jonesP)) / 0.2 > 92.9):
    print("It is not possible to get an A-")
else:
    print(str(round((a2 - ((1 - 0.2) * jonesP)) / 0.2, 2)) + "% to get an A-")
    
if ((b - ((1 - 0.2) * jonesP)) / 0.2 > 87.0):
    print("It is not possible to get an B+")
else:
    print(str(round((b - ((1 - 0.2) * jonesP)) / 0.2, 2)) + "% to get an B+")
    
if ((b1 - ((1 - 0.2) * jonesP)) / 0.2 > 83.0):
    print("It is not possible to get an B")
else:
    print(str(round((b1 - ((1 - 0.2) * jonesP)) / 0.2, 2)) + "% to get an B")
# Out:
# Student ID: 'doe123' grade so far is: 96.17
# It is not possible to get an A+
# 80.32% to get an A
# 65.32% to get an A-
# 50.32% to get an B+
# 30.32% to get an B
#
# Student ID: 'smith456' grade so far is: 86.81
# It is not possible to get an A+
# It is not possible to get an A
# It is not possible to get an A-
# It is not possible to get an B+
# 67.76% to get an B
#
# Student ID: 'jones789' grade so far is: 87.19
# It is not possible to get an A+
# It is not possible to get an A
# It is not possible to get an A-
# 86.24% to get an B+
# 66.24% to get an B
